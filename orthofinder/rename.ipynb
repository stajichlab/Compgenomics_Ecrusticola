# %% [markdown]
# # Rename assemblies

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import os 
from pathlib import Path
from os import listdir
from os.path import isfile, join

# %%
meta = pd.read_csv('filtered_metadata.tsv', delimiter="\t")  
#meta.head()

# %%
folder = './assemblies'
files = [f for f in listdir(folder) if isfile(join(folder, f))]
sorted_files = sorted(files)
file_df = pd.DataFrame(sorted_files)
file_df.columns = ['filename']
#file_df.head()

# %%
meta_sorted = meta.sort_values(by=['Assembly Accession'])
#meta_sorted.head()

# %%
file_df.reset_index(drop=True, inplace=True)
meta_sorted.reset_index(drop=True, inplace=True)
combined_df = pd.concat([file_df, meta_sorted], axis=1)
#combined_df.head()
# Out:
#                                             filename Assembly Accession  \
# 0         GCA_000230625.1_Exop_derm_V1_genomic.fasta    GCA_000230625.1
# 1  GCA_000709125.1_Exop_aqua_CBS_119918_V1_genomi...    GCA_000709125.1
# 2  GCA_000835395.1_Exop_side_CBS121828_V1_genomic...    GCA_000835395.1
# 3  GCA_000835505.1_Exop_xeno_CBS118157_V1_genomic...    GCA_000835505.1
# 4  GCA_000835515.1_Exop_olig_CBS72588_V1_genomic....    GCA_000835515.1
#
#              Assembly Name                      Organism Name  \
# 0             Exop_derm_V1  Exophiala dermatitidis NIH/UT8656
# 1  Exop_aqua_CBS_119918_V1    Exophiala aquamarina CBS 119918
# 2   Exop_side_CBS121828_V1                  Exophiala sideris
# 3   Exop_xeno_CBS118157_V1              Exophiala xenobiotica
# 4    Exop_olig_CBS72588_V1              Exophiala oligosperma
#
#    Organism Infraspecific Names Breed Organism Infraspecific Names Strain  \
# 0                                 NaN                          NIH/UT8656
# 1                                 NaN                          CBS 119918
# 2                                 NaN                          CBS 121828
# 3                                 NaN                          CBS 118157
# 4                                 NaN                           CBS 72588
#
#    Organism Infraspecific Names Cultivar  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Organism Infraspecific Names Ecotype Organism Infraspecific Names Isolate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    Organism Infraspecific Names Sex  ... Assembly Stats Contig N50  \
# 0                               NaN  ...                  259861.0
# 1                               NaN  ...                  528423.0
# 2                               NaN  ...                  917331.0
# 3                               NaN  ...                 1212368.0
# 4                               NaN  ...                  973116.0
#
#   Assembly Stats Scaffold N50 Assembly Stats Number of Scaffolds  \
# 0                   3623950.0                               10.0
# 1                   2236061.0                              151.0
# 2                   7897194.0                                5.0
# 3                   5039080.0                               15.0
# 4                   3385568.0                              143.0
#
#   Annotation BUSCO Complete   Annotation BUSCO Single Copy   \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    Annotation BUSCO Duplicated   Annotation BUSCO Fragmented   \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Annotation BUSCO Missing   Annotation BUSCO Lineage   \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    Assembly Sequencing Tech
# 0                  Illumina
# 1                  Illumina
# 2                  Illumina
# 3                  Illumina
# 4                  Illumina
#
# [5 rows x 24 columns]

# %%
dir = 'assemblies/'
files = [f for f in listdir(folder) if isfile(join(folder, f))]
files_dir = [dir + f for f in files]
files_dir_df = pd.DataFrame(files_dir)
files_dir_df.columns = ['Path']
files_dir_df_sorted = files_dir_df.sort_values(by='Path')
#files_dir_df_sorted

# %%
files_dir_df_sorted.reset_index(drop=True, inplace=True)
combined_df_final = pd.concat([files_dir_df_sorted, combined_df], axis=1)
combined_df_final['directory'] = 'assemblies'
combined_df_final['extension'] = '.fasta'
combined_df_final.head()
# Out:
#                                                 Path  \
# 0  assemblies/GCA_000230625.1_Exop_derm_V1_genomi...
# 1  assemblies/GCA_000709125.1_Exop_aqua_CBS_11991...
# 2  assemblies/GCA_000835395.1_Exop_side_CBS121828...
# 3  assemblies/GCA_000835505.1_Exop_xeno_CBS118157...
# 4  assemblies/GCA_000835515.1_Exop_olig_CBS72588_...
#
#                                             filename Assembly Accession  \
# 0         GCA_000230625.1_Exop_derm_V1_genomic.fasta    GCA_000230625.1
# 1  GCA_000709125.1_Exop_aqua_CBS_119918_V1_genomi...    GCA_000709125.1
# 2  GCA_000835395.1_Exop_side_CBS121828_V1_genomic...    GCA_000835395.1
# 3  GCA_000835505.1_Exop_xeno_CBS118157_V1_genomic...    GCA_000835505.1
# 4  GCA_000835515.1_Exop_olig_CBS72588_V1_genomic....    GCA_000835515.1
#
#              Assembly Name                      Organism Name  \
# 0             Exop_derm_V1  Exophiala dermatitidis NIH/UT8656
# 1  Exop_aqua_CBS_119918_V1    Exophiala aquamarina CBS 119918
# 2   Exop_side_CBS121828_V1                  Exophiala sideris
# 3   Exop_xeno_CBS118157_V1              Exophiala xenobiotica
# 4    Exop_olig_CBS72588_V1              Exophiala oligosperma
#
#    Organism Infraspecific Names Breed Organism Infraspecific Names Strain  \
# 0                                 NaN                          NIH/UT8656
# 1                                 NaN                          CBS 119918
# 2                                 NaN                          CBS 121828
# 3                                 NaN                          CBS 118157
# 4                                 NaN                           CBS 72588
#
#    Organism Infraspecific Names Cultivar  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Organism Infraspecific Names Ecotype Organism Infraspecific Names Isolate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    ...  Assembly Stats Number of Scaffolds Annotation BUSCO Complete   \
# 0  ...                                10.0                        NaN
# 1  ...                               151.0                        NaN
# 2  ...                                 5.0                        NaN
# 3  ...                                15.0                        NaN
# 4  ...                               143.0                        NaN
#
#   Annotation BUSCO Single Copy  Annotation BUSCO Duplicated   \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   Annotation BUSCO Fragmented   Annotation BUSCO Missing   \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    Annotation BUSCO Lineage   Assembly Sequencing Tech   directory  extension
# 0                        NaN                  Illumina  assemblies     .fasta
# 1                        NaN                  Illumina  assemblies     .fasta
# 2                        NaN                  Illumina  assemblies     .fasta
# 3                        NaN                  Illumina  assemblies     .fasta
# 4                        NaN                  Illumina  assemblies     .fasta
#
# [5 rows x 27 columns]

# %%
combined_df_final['new_name'] = combined_df_final['Organism Name'] + combined_df_final['extension']
combined_df_final.head()
# Out:
#                                                 Path  \
# 0  assemblies/GCA_000230625.1_Exop_derm_V1_genomi...
# 1  assemblies/GCA_000709125.1_Exop_aqua_CBS_11991...
# 2  assemblies/GCA_000835395.1_Exop_side_CBS121828...
# 3  assemblies/GCA_000835505.1_Exop_xeno_CBS118157...
# 4  assemblies/GCA_000835515.1_Exop_olig_CBS72588_...
#
#                                             filename Assembly Accession  \
# 0         GCA_000230625.1_Exop_derm_V1_genomic.fasta    GCA_000230625.1
# 1  GCA_000709125.1_Exop_aqua_CBS_119918_V1_genomi...    GCA_000709125.1
# 2  GCA_000835395.1_Exop_side_CBS121828_V1_genomic...    GCA_000835395.1
# 3  GCA_000835505.1_Exop_xeno_CBS118157_V1_genomic...    GCA_000835505.1
# 4  GCA_000835515.1_Exop_olig_CBS72588_V1_genomic....    GCA_000835515.1
#
#              Assembly Name                      Organism Name  \
# 0             Exop_derm_V1  Exophiala dermatitidis NIH/UT8656
# 1  Exop_aqua_CBS_119918_V1    Exophiala aquamarina CBS 119918
# 2   Exop_side_CBS121828_V1                  Exophiala sideris
# 3   Exop_xeno_CBS118157_V1              Exophiala xenobiotica
# 4    Exop_olig_CBS72588_V1              Exophiala oligosperma
#
#    Organism Infraspecific Names Breed Organism Infraspecific Names Strain  \
# 0                                 NaN                          NIH/UT8656
# 1                                 NaN                          CBS 119918
# 2                                 NaN                          CBS 121828
# 3                                 NaN                          CBS 118157
# 4                                 NaN                           CBS 72588
#
#    Organism Infraspecific Names Cultivar  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Organism Infraspecific Names Ecotype Organism Infraspecific Names Isolate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    ...  Annotation BUSCO Complete  Annotation BUSCO Single Copy   \
# 0  ...                         NaN                           NaN
# 1  ...                         NaN                           NaN
# 2  ...                         NaN                           NaN
# 3  ...                         NaN                           NaN
# 4  ...                         NaN                           NaN
#
#   Annotation BUSCO Duplicated  Annotation BUSCO Fragmented   \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Annotation BUSCO Missing   Annotation BUSCO Lineage   \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    Assembly Sequencing Tech   directory  extension  \
# 0                  Illumina  assemblies     .fasta
# 1                  Illumina  assemblies     .fasta
# 2                  Illumina  assemblies     .fasta
# 3                  Illumina  assemblies     .fasta
# 4                  Illumina  assemblies     .fasta
#
#                                   new_name
# 0  Exophiala dermatitidis NIH/UT8656.fasta
# 1    Exophiala aquamarina CBS 119918.fasta
# 2                  Exophiala sideris.fasta
# 3              Exophiala xenobiotica.fasta
# 4              Exophiala oligosperma.fasta
#
# [5 rows x 28 columns]
